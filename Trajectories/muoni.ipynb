# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Tau Antitau

# %%
input_file_antiel = uproot.open("AntiNeutMuon.root")
antiel = input_file_antiel["t"]
kin_antiel = antiel["Ekin"].array()
x_antiel, y_antiel = antiel["x"].array(), antiel["y"].array()
xcos_antiel, ycos_antiel = antiel["x_cos"].array(), antiel["y_cos"].array()
weight_antiel = antiel["weight"].array()

input_file_el = uproot.open("NeutMuon.root")
el = input_file_el["t"]
kin_el = el["Ekin"].array()
x_el, y_el = el["x"].array(), el["y"].array()
xcos_el, ycos_el = el["x_cos"].array(), el["y_cos"].array()
weight_el = el["weight"].array()

# %%
#''''''''''
# selezioni i neutrini che arrivano al rivelatore
kin_antiel = kin_antiel[
    np.logical_and(
        np.logical_and(x_antiel < -8.0, x_antiel > -47.6),
        np.logical_and(y_antiel < 55.1, y_antiel > 15.5),
    )
]

x_antiel1 = x_antiel[
    np.logical_and(
        np.logical_and(x_antiel < -8.0, x_antiel > -47.6),
        np.logical_and(y_antiel < 55.1, y_antiel > 15.5),
    )
]

y_antiel1 = y_antiel[
    np.logical_and(
        np.logical_and(x_antiel < -8.0, x_antiel > -47.6),
        np.logical_and(y_antiel < 55.1, y_antiel > 15.5),
    )
]


xcos_antiel = xcos_antiel[
    np.logical_and(
        np.logical_and(x_antiel < -8.0, x_antiel > -47.6),
        np.logical_and(y_antiel < 55.1, y_antiel > 15.5),
    )
]

ycos_antiel = ycos_antiel[
    np.logical_and(
        np.logical_and(x_antiel < -8.0, x_antiel > -47.6),
        np.logical_and(y_antiel < 55.1, y_antiel > 15.5),
    )
]





weight_antiel = weight_antiel[
    np.logical_and(
        np.logical_and(x_antiel < -8.0, x_antiel > -47.6),
        np.logical_and(y_antiel < 55.1, y_antiel > 15.5),
    )
]





kin_el = kin_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]

x_el1 = x_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]

y_el1 = y_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]


xcos_el = xcos_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]

ycos_el = ycos_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]





weight_el = weight_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]

#'''''''''
norm_antiel = 214285714

weight_antiel_1 = weight_antiel[weight_antiel == 1]
kin_antiel_1 = kin_antiel[weight_antiel == 1]
weight_antiel_not1 = weight_antiel[weight_antiel != 1]
kin_antiel_not1 = kin_antiel[weight_antiel != 1]
xcos_antiel_1 = xcos_antiel[weight_antiel == 1]
xcos_antiel_not1 = xcos_antiel[weight_antiel != 1]
ycos_antiel_1 = ycos_antiel[weight_antiel == 1]
ycos_antiel_not1 = ycos_antiel[weight_antiel != 1]
# spettro antielettronici

norm_antiel = 214285714
print(len(xcos_antiel),len(x_antiel1))
# Out:
# 1312407 1312407

# %%
#'''''''''
# selezioni i neutrini che arrivano al rivelatore
kin_el = kin_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]

x_el1 = x_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]

y_el1 = y_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]


xcos_el = xcos_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]

ycos_el = ycos_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]





weight_el = weight_el[
    np.logical_and(
        np.logical_and(x_el < -8.0, x_el > -47.6),
        np.logical_and(y_el < 55.1, y_el > 15.5),
    )
]

#'''''''''
norm_el = 214285714

weight_el_1 = weight_el[weight_el == 1]
kin_el_1 = kin_el[weight_el == 1]
weight_el_not1 = weight_el[weight_el != 1]
kin_el_not1 = kin_el[weight_el != 1]
xcos_el_1 = xcos_el[weight_el == 1]
xcos_el_not1 = xcos_el[weight_el != 1]
ycos_el_1 = ycos_el[weight_el == 1]
ycos_el_not1 = ycos_el[weight_el != 1]
# spettro elettronici

norm_el = 214285714
print(len(xcos_el),len(x_el1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-202bed249abd> in <module>
#       1 #'''''''''
#       2 # selezioni i neutrini che arrivano al rivelatore
# ----> 3 kin_el = kin_el[
#       4     np.logical_and(
#       5         np.logical_and(x_el < -8.0, x_el > -47.6),
#
# ~\anaconda3\lib\site-packages\awkward\highlevel.py in __getitem__(self, where)
#     991         """
#     992         if not hasattr(self, "_tracers"):
# --> 993             tmp = ak._util.wrap(self.layout[where], self._behavior)
#     994         else:
#     995             tmp = ak._connect._jax.jax_utils._jaxtracers_getitem(self, where)
#
# ValueError: in NumpyArray attempting to get 1691486, index out of range
#
# (https://github.com/scikit-hep/awkward-1.0/blob/1.4.0/src/cpu-kernels/awkward_regularize_arrayslice.cpp#L18)

# %%
values_x, bins_x, patches_x = plt.hist(x_antiel1,bins= 30,
                                       weights=weight_antiel*norm_antiel,
                                       histtype='step',hatch='xxxxx',color='teal')

plt.show()
values_y, bins_y, patches_y = plt.hist(y_antiel1,bins= 30,
                                       weights=weight_antiel*norm_antiel,
                                       histtype='step',hatch='xxxxx',color='orange')
plt.show()

#### 2d map
import awkward
import matplotlib as mpl
x1_antiel=awkward.to_numpy(x_antiel1)
y1_antiel=awkward.to_numpy(y_antiel1)
we1_antiel=awkward.to_numpy(weight_antiel*norm_antiel)
fig,ax = plt.subplots()
histogram = ax.hist2d(x1_antiel,y1_antiel,
                      range=[[-47.6,-8.0],[15.5,55.1]],
                      #range=[[-60,0],[0,70]],
                      bins=[10,10],
                      cmap='plasma',
                      weights=we1_antiel,
                      norm=mpl.colors.LogNorm()
                     )

ax.set_xlabel('x [cm]')
ax.set_ylabel('y [cm]')
ax.set_title('anti-')
#plt.title('anti-$\N{small greek letter nu}')
fig.colorbar(histogram[3],ax = ax)

plt.show()

# %%
values_x, bins_x, patches_x = plt.hist(x_el1,bins= 30,
                                       weights=weight_el*norm_el,
                                       histtype='step',hatch='xxxxx',color='teal')

plt.show()
values_y, bins_y, patches_y = plt.hist(y_el1,bins= 30,
                                       weights=weight_el*norm_el,
                                       histtype='step',hatch='xxxxx',color='orange')
plt.show()

#### 2d map
import awkward
import matplotlib as mpl
x1_el=awkward.to_numpy(x_el1)
y1_el=awkward.to_numpy(y_el1)
we1_el=awkward.to_numpy(weight_el*norm_el)
fig,ax = plt.subplots()
histogram = ax.hist2d(x1_el,y1_el,
                      range=[[-47.6,-8.0],[15.5,55.1]],
                      #range=[[-60,0],[0,70]],
                      bins=[10,10],
                      cmap='plasma',
                      weights=we1_el,
                      norm=mpl.colors.LogNorm()
                     )

ax.set_xlabel('x [cm]')
ax.set_ylabel('y [cm]')
ax.set_title('anti-')
#plt.title('anti-$\N{small greek letter nu}')
fig.colorbar(histogram[3],ax = ax)

plt.show()

# %%
kin_antiel=awkward.to_numpy(kin_antiel)
pseudo_antiel=awkward.to_numpy(pseudo_antiel)

# %% [markdown]
# ### Angolo e pseudorapidità

# %%
angle_antiel=(xcos_antiel**2+ycos_antiel**2)**(1/2)
#print(len(angle_antiel),len(weight_antiel))
plt.hist(angle_antiel,
         bins= 30,
         weights=weight_antiel*norm_antiel,
         histtype='step',hatch='xxxxx',color='pink',log=True)
plt.xlabel('angle')
plt.show()
pseudo_antiel = -np.log(np.tan(angle_antiel/2))
plt.hist(pseudo_antiel,
         bins= 30,
         weights=weight_antiel*norm_antiel,
         histtype='step',
         #hatch='xxxxx',
         color='firebrick',log=True)
plt.ylim([100,10**11])
plt.xlabel('pseudorapidity')
plt.show()

# %%
angle_el=(xcos_el**2+ycos_el**2)**(1/2)
#print(len(angle_el),len(weight_el))
plt.hist(angle_el,
         bins= 30,
         weights=weight_el*norm_el,
         histtype='step',hatch='xxxxx',color='pink',log=True)
plt.xlabel('angle')
plt.show()
pseudo_el = -np.log(np.tan(angle_el/2))
plt.hist(pseudo_el,
         bins= 30,
         weights=weight_el*norm_el,
         histtype='step',
         #hatch='xxxxx',
         color='firebrick',log=True)
plt.ylim([100,10**11])
plt.xlabel('pseudorapidity')
plt.show()

# %%
plt.scatter(kin_antiel,pseudo_antiel,s=19,color='teal',marker='s')
plt.scatter(kin_el,pseudo_el,s=19,color='indianred',marker='s')
plt.xscale('log')

# %%
#kin_array = np.array(kin_antiel)
#pseudo_array = np.array(pseudo_antiel)
kin_antiel_array=awkward.to_numpy(kin_antiel)
pseudo_antiel_array=awkward.to_numpy(pseudo_antiel)
colors=['white','teal','indianred']
import matplotlib as mp
we1_antiel=awkward.to_numpy(weight_antiel*norm_antiel)
fig,ax = plt.subplots()
histogram = ax.hist2d(kin_antiel_array,pseudo_antiel_array,
                      range=[[1,5000],[6,10]],
                      #range=[[-60,0],[0,70]],
                      #bins=[np.logspace(,10],
                      bins=[np.logspace(np.log(1),np.log(5000),150),75],
                      #bins=[100,100],
                      cmap=plt.cm.RdYlBu_r,
                      weights=we1_antiel,
                      norm=mpl.colors.LogNorm(vmin=10**8,vmax=0.3*10**11)
                     )

#print(np.logspace(np.log,,100),type(np.logspace(1,5000,100)))

ax.set_xlabel('x [cm]')
ax.set_ylabel('y [cm]')
ax.set_title('anti-')
#plt.title('anti-$\N{small greek letter nu}')
fig.colorbar(histogram[3],ax = ax)
plt.xscale('log')
plt.xlim(10,5000)
plt.ylim(6.9,10)
plt.show()

#pseudo_array = np.array(pseudo_el)
kin_el_array=awkward.to_numpy(kin_el)
pseudo_el_array=awkward.to_numpy(pseudo_el)
colors=['white','teal','indianred']
import matplotlib as mp
we1_el=awkward.to_numpy(weight_el*norm_el)
fig,ax = plt.subplots()
histogram = ax.hist2d(kin_el_array,pseudo_el_array,
                      range=[[1,5000],[6,10]],
                      #range=[[-60,0],[0,70]],
                      #bins=[np.logspace(,10],
                      bins=[np.logspace(np.log(1),np.log(5000),150),75],
                      #bins=[100,100],
                      cmap=plt.cm.RdYlBu_r,
                      weights=we1_el,
                      norm=mpl.colors.LogNorm(vmin=10**8,vmax=0.3*10**11)
                     )

#print(np.logspace(np.log,,100),type(np.logspace(1,5000,100)))

ax.set_xlabel('x [cm]')
ax.set_ylabel('y [cm]')
ax.set_title('anti-')
#plt.title('anti-$\N{small greek letter nu}')
fig.colorbar(histogram[3],ax = ax)
plt.xscale('log')
plt.xlim(10,5000)
plt.ylim(6.9,10)
plt.show()

# %%
#kin = kin_el_array + kin_antiel_array
#pseudo = pseudo_el_array + pseudo_antiel_array
fig,ax = plt.subplots()
histogram = ax.hist2d(kin_antiel_array,pseudo_antiel_array,
                      range=[[1,5000],[6,10]],
                      #range=[[-60,0],[0,70]],
                      #bins=[np.logspace(,10],
                      bins=[np.logspace(np.log(1),np.log(5000),200),75],
                      #bins=[100,100],
                      cmap=plt.cm.RdYlBu_r,
                      weights=we1_antiel,
                      norm=mpl.colors.LogNorm()
                     )

histogram = ax.hist2d(kin_el_array,pseudo_el_array,
                      range=[[1,5000],[6,10]],
                      #range=[[-60,0],[0,70]],
                      #bins=[np.logspace(,10],
                      bins=[np.logspace(np.log(1),np.log(5000),200),75],
                      #bins=[100,100],
                      cmap=plt.cm.RdYlBu_r,
                      weights=we1_el,
                      norm=mpl.colors.LogNorm(vmin=10**8,vmax=0.3*10**11)
                     )
#print(np.logspace(np.log,,100),type(np.logspace(1,5000,100)))

ax.set_xlabel('')
ax.set_ylabel('$\N{greek small letter eta}$')
ax.set_title('$\N{greek small letter nu}_\N{greek small letter mu}$ + anti-$\N{greek small letter nu}_\N{greek small letter mu}$')
ax.set_facecolor('gainsboro')
#plt.title('anti-$\N{small greek letter nu}')
fig.colorbar(histogram[3],ax = ax)
plt.xscale('log')
plt.xlim(10,5000)
plt.ylim(6.9,10)
plt.show()

# %% [markdown]
# # Particolari

# %%
from matplotlib import cm
import matplotlib.colors as colors
fig, ax = plt.subplots()
q = ax.quiver(x_antiel1, y_antiel1, xcos_antiel, ycos_antiel,width=0.00139,scale=0.09)
#ax.quiverkey(q, X=0.1, Y=5.1, U=5, label='Quiver key, length = 10', labelpos='E')
ax.quiverkey(q, 9.9, 9.9, 5.5, r'$1 \frac{m}{s}$', labelpos='E',
                   coordinates='figure')

ax.set_ylabel('y [cm]')
ax.set_xlabel('x [cm]')
ax.set_title('Proiezioni assi x e y (neutrini tau)')
ax.scatter(x_antiel1, y_antiel1 ,color='0.5', s=0.1)
fig.set_size_inches(23.5, 13.5)
plt.show()

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.colors as colors



thetaplasmafig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

PSEUDO_antiel = np.array(pseudo_antiel)
c = np.abs(PSEUDO_antiel)
#C_lati = np.abs(theta_lati)
#C_centro = np.abs(theta_centro)
X_antiel = np.array(x_antiel1)
Y_antiel = np.array(y_antiel1)

box = ax.scatter(X_antiel, Y_antiel, 
                 np.ones_like(X_antiel)*0, 
                 #PSEUDO_antiel,
                 PSEUDO_antiel, s = 19,  c = c, alpha = 1, cmap = cm.plasma,
                 norm=colors.LogNorm(vmin=min(PSEUDO_antiel), vmax=max(PSEUDO_antiel)), label = 'angoli',
                 )

ax.set_title('$\N{greek small letter chi}^2$ 3d colormap (post-correzione)')
plt.colorbar(box,shrink=0.399)
#figure(figsize=(15, 15), dpi=80)
#ax.legend()

plt.show()
# Out:
# C:\Users\diesi\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:838: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if zdir == 'x':
# C:\Users\diesi\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:840: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif zdir == 'y':

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.tri as mtri
fig = plt.figure(figsize=plt.figaspect(0.5))

# Triangulate parameter space to determine the triangles
tri = mtri.Triangulation(X_antiel, Y_antiel)

# Plot the surface.  The triangles in parameter space determine which x, y, z
# points are connected by an edge.
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_trisurf(Y_antiel, X_antiel, PSEUDO_antiel, triangles=tri.triangles, cmap=plt.cm.plasma)
fig.set_size_inches(23.5, 13.5)
ax.set_xlabel('y [cm]')
ax.set_ylabel('x [cm]')
ax.set_zlabel('pseudorapidità')
ax.set_title('Pseudorapidità vs Posizione (neutrini tauonici)')
plt.show()

# %% [markdown]
# ### Differenze pions/kaons

# %%
angle_antiel_1=(xcos_antiel_1**2+ycos_antiel_1**2)**(1/2)
angle_antiel_not1=(xcos_antiel_not1**2+ycos_antiel_not1**2)**(1/2)

pseudo_antiel_1 = -np.log(np.tan(angle_antiel_1/2))
pseudo_antiel_not1 = -np.log(np.tan(angle_antiel_not1/2))

plt.hist(pseudo_antiel_1,
         bins= 30,
         weights=weight_antiel_1*norm_antiel,
         histtype='step',
         #hatch='xxxxx',
         color='teal',log=True, label='1')

plt.hist(pseudo_antiel_not1,
         bins= 30,
         weights=weight_antiel_not1*norm_antiel,
         histtype='step',
         #hatch='xxxxx',
         color='indianred',log=True, label='not 1')




plt.ylim([100,10**11])
plt.xlabel('pseudorapidity')
plt.show()
